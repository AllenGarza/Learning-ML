# %%
from webscraper import Webscraper
import os
import sys
import re
import pandas as pd
from datetime import date

curr_dir = os.getcwd()
df = pd.read_csv(os.path.join(curr_dir, 'articles'))
df
# Out:
#   Unnamed: 0                                                  0  \
# 0     apnews  prince-philip-england-coronavirus-pandemic-pri...
# 1    reuters                                                NaN
#
#                                                    1  \
# 0  prince-philip-england-coronavirus-pandemic-pri...
# 1                                                NaN
#
#                                                    2  \
# 0  prince-philip-england-coronavirus-pandemic-pri...
# 1                                                NaN
#
#                                                    3  \
# 0  prince-philip-england-coronavirus-pandemic-pri...
# 1                                                NaN
#
#                                                    4  \
# 0  prince-philip-england-coronavirus-pandemic-pri...
# 1                                                NaN
#
#                                                    5  \
# 0  prince-philip-england-coronavirus-pandemic-pri...
# ...

# %%
df = df.transpose()
df = df.iloc
# Out:
#                  0
# Unnamed: 0  apnews

# %%
apnews_link_ex1 = df.iloc[3,1]
apnews_link_ex2 = df.iloc[88,1]
apnews_link_ex3 = df.iloc[9,1]
                         
                         

print('ex1: ', apnews_link_ex1)
print('ex2: ', apnews_link_ex2)
print('ex3: ', apnews_link_ex3)
# Out:
# ex1:  ('americas', 'canadian-police-refuse-provincial-order-make-random-stops-amid-covid-19-surge-2021-04-17')
# ex2:  nan
# ex3:  ('world', 'special-report-health-official-alleges-sexual-slavery-tigray-women-blame-2021-04-15')
