# %%
from webscraper import Webscraper
import os
import sys
import re
import pandas as pd
from datetime import date

curr_dir = os.getcwd()
df = pd.read_csv(os.path.join(curr_dir, 'articles'))
df = df.drop_duplicates()
df
# Out:
#      Unnamed: 0                                             apnews  \
# 0             0  /article/prince-philip-england-coronavirus-pan...
# 1             1  /article/prince-philip-england-coronavirus-pan...
# 2             2  /article/prince-philip-england-coronavirus-pan...
# 3             3  https://facebook.com/dialog/share?app_id=87061...
# 4             4  https://twitter.com/intent/tweet?url=https://a...
# ..          ...                                                ...
# 226         226  /article/prince-charles-prince-philip-viscount...
# 227         227  /article/prince-charles-prince-philip-viscount...
# 228         228  /article/iran-uranium-enrichment-60-percent-ed...
# 229         229  /article/iran-uranium-enrichment-60-percent-ed...
# 230         230  /article/iran-uranium-enrichment-60-percent-ed...
#
#                                                reuters  \
# 0    /technology/exclusive-chinas-ant-explores-ways...
# 1    /world/americas/biden-says-he-will-raise-us-ca...
# 2    /world/uk/queen-elizabeth-britain-bid-farewell...
# 3    /world/americas/canadian-police-refuse-provinc...
# 4    /world/czechs-expel-russian-embassy-staff-pm-s...
# ..                                                 ...
# 226                                                NaN
# 227                                                NaN
# 228                                                NaN
# 229                                                NaN
# 230                                                NaN
#
#                                         washingtonpost  \
# 0    https://www.washingtonpost.com/us-policy/2021/...
# 1    https://www.washingtonpost.com/nation/2021/04/...
# 2    https://www.washingtonpost.com/politics/indian...
# 3    https://www.washingtonpost.com/politics/rnc-ch...
# 4    https://www.washingtonpost.com/politics/rnc-ch...
# ..                                                 ...
# 226                                                NaN
# 227                                                NaN
# 228                                                NaN
# 229                                                NaN
# 230                                                NaN
#
#                                                nytimes
# 0    /2021/04/16/podcasts/ufo-sightings-space-x-sac...
# 1    /2021/04/16/podcasts/ufo-sightings-space-x-sac...
# 2    /2021/04/15/podcasts/still-processing-lil-nas-...
# 3    /2021/04/15/podcasts/still-processing-lil-nas-...
# 4    /2021/04/16/books/review/podcast-15th-annivers...
# ..                                                 ...
# 226                                                NaN
# 227                                                NaN
# 228                                                NaN
# 229                                                NaN
# 230                                                NaN
#
# [231 rows x 5 columns]
