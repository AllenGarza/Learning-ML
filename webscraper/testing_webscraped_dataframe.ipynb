# %%
from webscraper import Webscraper
import os
import sys
import re
import pandas as pd

curr_dir = os.getcwd()
df = pd.read_csv(os.path.join(curr_dir, 'articles'))
df = df.drop_duplicates()
df
# Out:
#      Unnamed: 0                                             apnews  \
# 0             0  <a class="Component-headline-0-2-68" data-key=...
# 1             1  <a class="Component-asBlock-0-2-53 Component-d...
# 2             2  <a class="Component-asBlock-0-2-53 Component-d...
# 3             3  <a class="Component-root-0-2-76" href="https:/...
# 4             4  <a class="Component-root-0-2-77" href="https:/...
# ..          ...                                                ...
# 217         229  <a class="image-0-2-102" href="/article/us-job...
# 218         230  <a class="firstWords-0-2-103" data-key="story-...
# 219         231  <a class="Component-headline-0-2-68" data-key=...
# 220         232  <a class="image-0-2-102" href="/article/middle...
# 221         233  <a class="firstWords-0-2-103" data-key="story-...
#
#                                                reuters  \
# 0    <a class="MediaStoryCard__basic_hero___fSAEnM ...
# ...
